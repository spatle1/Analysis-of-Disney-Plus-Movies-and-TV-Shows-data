# %%
DISNEY PLUS MOVIES AND TV SHOWS

Disney Plus dataset consists of TV shows and movies data. The dataset is taken from Kaggle. For data processing I used Pandas and Numpy library. Also for visualize I used matplotlib and seaborn library.

# %%
1. Connection to mongodb

# %%
import sys
from pymongo import MongoClient

client = MongoClient('mongodb://localhost:27017/')
db = client.Project3
collection = db.disney_plus
print("Connected to MongoDB Server")
# Out:
# Connected to MongoDB Server

# %%
Import all necessary Libraries

# %%
import numpy as np
import pprint
import pandas as pd
import jovian
import matplotlib.pyplot as plt
import seaborn as sns
print("Libraries imported")
# Out:
# Libraries imported

# %%
TASK
1. Display all movies according to marvel timeline

# %%
cursor_2 = collection.find({"rating": {"$in" : ["PG-13", "PG"]},"country": "India"}).sort('marvel_t')
df = pd.DataFrame(list(cursor_2))
df.head(15)
# Out:
#                          _id show_id   type  \
# 0   62741383fd923b2544ade3b2   s1042  Movie
# 1   62741383fd923b2544ade3b4   s1044  Movie
# 2   62741383fd923b2544ade3b8   s1048  Movie
# 3   62741383fd923b2544ade3b9   s1049  Movie
# 4   62741383fd923b2544ade3ac   s1036  Movie
# 5   62741383fd923b2544ade3bc   s1052  Movie
# 6   62741383fd923b2544ade3bb   s1051  Movie
# 7   62741383fd923b2544ade3bd   s1053  Movie
# 8   62741383fd923b2544ade3ba   s1050  Movie
# 9   62741383fd923b2544ade3b3   s1043  Movie
# 10  62741383fd923b2544ade3b6   s1046  Movie
# 11  62741383fd923b2544ade3b7   s1047  Movie
# 12  62741383fd923b2544ade3af   s1039  Movie
# 13  62741383fd923b2544ade3ae   s1038  Movie
# 14  62741383fd923b2544ade3b1   s1041  Movie
#
#                                                 title  \
# 0   Marvel Studios' Captain America: The First Ave...
# 1                      Marvel Studios' Captain Marvel
# 2                            Marvel Studios' Iron Man
# ...

# %%
Then Put all data in curser

# %%
cursor = collection.find()
df = pd.DataFrame(list(cursor))
df
# Out:
#                            _id show_id     type  \
# 0     62741383fd923b2544addfa1      s1    Movie
# 1     62741383fd923b2544addfa2      s2    Movie
# 2     62741383fd923b2544addfa3      s3    Movie
# 3     62741383fd923b2544addfa4      s4    Movie
# 4     62741383fd923b2544addfa5      s5  TV Show
# ...                        ...     ...      ...
# 1444  62741383fd923b2544ade545   s1445    Movie
# 1445  62741383fd923b2544ade546   s1446    Movie
# 1446  62741383fd923b2544ade547   s1447    Movie
# 1447  62741383fd923b2544ade548   s1448    Movie
# 1448  62741383fd923b2544ade549   s1449    Movie
#
#                                                  title  \
# 0     Duck the Halls: A Mickey Mouse Christmas Special
# 1                               Ernest Saves Christmas
# 2                         Ice Age: A Mammoth Christmas
# 3                           The Queen Family Singalong
# 4                                The Beatles: Get Back
# ...

# %%
just cross check number of rows and column

# %%
df.shape
# Out:
# (1449, 14)

# %%
Make a copy of orginal data and remove unwanted column for task 2(Realation between type and rating)

# %%
disney_plus_df_copy = df.copy()
disney_plus_df = df.copy()

disney_plus_df_copy.drop(['director','cast','date_added','marvel_t'],axis=1,inplace=True)
disney_plus_df_copy
# Out:
#                            _id show_id     type  \
# 0     62741383fd923b2544addfa1      s1    Movie
# 1     62741383fd923b2544addfa2      s2    Movie
# 2     62741383fd923b2544addfa3      s3    Movie
# 3     62741383fd923b2544addfa4      s4    Movie
# 4     62741383fd923b2544addfa5      s5  TV Show
# ...                        ...     ...      ...
# 1444  62741383fd923b2544ade545   s1445    Movie
# 1445  62741383fd923b2544ade546   s1446    Movie
# 1446  62741383fd923b2544ade547   s1447    Movie
# 1447  62741383fd923b2544ade548   s1448    Movie
# 1448  62741383fd923b2544ade549   s1449    Movie
#
#                                                  title  \
# 0     Duck the Halls: A Mickey Mouse Christmas Special
# 1                               Ernest Saves Christmas
# 2                         Ice Age: A Mammoth Christmas
# 3                           The Queen Family Singalong
# 4                                The Beatles: Get Back
# ...

# %%
disney_plus_df_copy['country'].replace(np.NaN,'United kingdom',inplace=True)

# %%
New object for rating is created so it wont affect orginal

# %%
disney_plus_df_copy['rating']
# Out:
# 0        TV-G
# 1          PG
# 2        TV-G
# 3       TV-PG
# 4         NaN
#         ...
# 1444       PG
# 1445    PG-13
# 1446       PG
# 1447    PG-13
# 1448    PG-13
# Name: rating, Length: 1449, dtype: object

# %%
check how many null value is there

# %%
disney_plus_df_copy.isnull().sum()
# Out:
# _id             0
# show_id         0
# type            0
# title           0
# country         0
# release_year    0
# rating          3
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
Replace those null

# %%
disney_plus_df_copy['rating'].replace(np.NaN,'TV-MA',inplace=True)

disney_plus_df_copy
# Out:
#                            _id show_id     type  \
# 0     62741383fd923b2544addfa1      s1    Movie
# 1     62741383fd923b2544addfa2      s2    Movie
# 2     62741383fd923b2544addfa3      s3    Movie
# 3     62741383fd923b2544addfa4      s4    Movie
# 4     62741383fd923b2544addfa5      s5  TV Show
# ...                        ...     ...      ...
# 1444  62741383fd923b2544ade545   s1445    Movie
# 1445  62741383fd923b2544ade546   s1446    Movie
# 1446  62741383fd923b2544ade547   s1447    Movie
# 1447  62741383fd923b2544ade548   s1448    Movie
# 1448  62741383fd923b2544ade549   s1449    Movie
#
#                                                  title  \
# 0     Duck the Halls: A Mickey Mouse Christmas Special
# 1                               Ernest Saves Christmas
# 2                         Ice Age: A Mammoth Christmas
# 3                           The Queen Family Singalong
# 4                                The Beatles: Get Back
# ...

# %%
disney_plus_df_copy.isnull().sum()
# Out:
# _id             0
# show_id         0
# type            0
# title           0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
Task 2: Releation between Type(movies or TV shows) and rating

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='rating',hue='type',data=disney_plus_df_copy)
plt.title('Relation between Type and Rating of Movies and TV Shows')
plt.show();

# %%
TASK 3. data segregation for different country as which country produce most number of shows and movies

# %%
Countries_data = disney_plus_df_copy.groupby('country').count().sort_values('title',ascending=False).head(10)

Countries_data.reset_index(inplace=True)
Countries_data
plt.bar(Countries_data.country,Countries_data.title);

# %%
TASK 4. Top 10 director based on most title for movies and tv shows

# %%
director_with_most_moviesshows_title = disney_plus_df.groupby('director').count().sort_values('rating',ascending=False).head(10)
director_with_most_moviesshows_title.reset_index(inplace=True)
plt.bar(director_with_most_moviesshows_title.director,director_with_most_moviesshows_title.title);

# %%
director_with_most_moviesshows_title
# Out:
#            director  _id  show_id  type  title  cast  country  date_added  \
# 0       Jack Hannah   17       17    17     17     2       17          17
# 1     John Lasseter   16       16    16     16    14       15          16
# 2         Paul Hoen   16       16    16     16    16       16          16
# 3   Charles Nichols   12       12    12     12     1       12          12
# 4  Robert Stevenson   12       12    12     12    12       12          12
# 5  Vincent McEveety   10       10    10     10    10       10          10
# 6      Bob Peterson   10       10    10     10    10       10          10
# 7   Wilfred Jackson    9        9     9      9     2        9           9
# 8      Kenny Ortega    9        9     9      9     9        9           9
# 9       James Algar    9        9     9      9     8        9           9
#
#    release_year  rating  duration  listed_in  description  marvel_t
# 0            17      17        17         17           17         0
# ...

# %%
TASK 5. Most movies and tv shows work Actor

# %%
most_successfully_Actor = disney_plus_df.groupby('cast').count().sort_values('title',ascending=False).head(1)

most_successfully_Actor.reset_index(inplace=True)
most_successfully_Actor
# Out:
#              cast  _id  show_id  type  title  director  country  date_added  \
# 0  Winston Hibler   10       10    10     10        10       10          10
#
#    release_year  rating  duration  listed_in  description  marvel_t
# 0            10      10        10         10           10         0
